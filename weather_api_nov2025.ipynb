# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTHICK20-jan/ENEC-Karthick/blob/main/weather_api_nov2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
response = requests.get("https://api.openweathermap.org/data/2.5/weather?q=Dubai&appid=79007029562c2ab46617d801d8018750&units=metric")
print(response.json())
# Out:
# {'coord': {'lon': 55.3047, 'lat': 25.2582}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 48, 'temp_min': 40.96, 'temp_max': 43.16, 'pressure': 997, 'humidity': 40}, 'visibility': 8000, 'wind': {'speed': 7.2, 'deg': 300}, 'clouds': {'all': 8}, 'dt': 1689506786, 'sys': {'type': 1, 'id': 7537, 'country': 'AE', 'sunrise': 1689471471, 'sunset': 1689520278}, 'timezone': 14400, 'id': 292223, 'name': 'Dubai', 'cod': 200}

# %%
import requests

def get_weather(city):
   url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"

   try:
       response= requests.get(url)
       weather_data = response.json()

       temperature = weather_data["main"]["temp"]
       humidity = weather_data["main"]["humidity"]
       max_temp = weather_data["main"]["temp_max"]
       min_temp = weather_data["main"]["temp_min"]
       wind_speed = weather_data["wind"]["speed"]
       sea_level = weather_data["main"]["sea_level"]
       pressure = weather_data["main"]["pressure"]


       print(f"Weather in {city}:")
       print(f"Temperature {temperature}°C:")
       print(f"Humidity : {humidity}%")
       print(f"Max Temperature: {max_temp}°C:")
       print(f"Min Temperature: {min_temp}°C:")
       print(f"Wind Speed: {wind_speed} m/s:")
       print(f"Sea Level: {sea_level} hPa:")
       print(f"Pressure: {pressure} hPa:")

   except requests.exceptions.RequestException:
        print("Error occured")


#usage
city_name = input("Enter the name of city:")
get_weather(city_name)
# Out:
# Enter the name of city:dubai
# Weather in dubai:
# Temperature 25.96°C:
# Humidity : 53%
# Max Temperature: 25.96°C:
# Min Temperature: 24.14°C:
# Wind Speed: 2.06 m/s:
# Sea Level: 1018 hPa:
# Pressure: 1018 hPa:

# %%
pip install gradio

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        return f"The current temperature in {city} is {temp}°C with {description}."
    else:
        return "Sorry, I couldn't find weather information for that city."

custom_css = """
/* Light Sky-Blue Animated Background */
body {
    background: linear-gradient(180deg, #b7e3ff, #9cd4ff, #7fc9ff, #aee4ff);
    background-size: 400% 400%;
    animation: skyMove 18s ease infinite;
}

@keyframes skyMove {
    0% { background-position: 0% 40%; }
    50% { background-position: 100% 60%; }
    100% { background-position: 0% 40%; }
}

/* Soft white cloud-like sparkles */
body::before {
    content: "";
    position: fixed;
    top: 0; left: 0;
    width: 100%; height: 100%;
    pointer-events: none;
    background-image: radial-gradient(rgba(255,255,255,0.9) 1px, transparent 1px);
    background-size: 6px 6px;
    opacity: 0.12;
    animation: glitter 6s linear infinite;
}

@keyframes glitter {
    0% { opacity: 0.1; }
    50% { opacity: 0.2; }
    100% { opacity: 0.1; }
}

/* Card styling */
.gradio-container {
    border-radius: 20px;
    padding: 25px !important;
    background: rgba(255, 255, 255, 0.45) !important;
    box-shadow: 0 0 25px rgba(150, 200, 255, 0.4);
    backdrop-filter: blur(12px);
}

input, textarea {
    border-radius: 12px !important;
}
"""

iface = gr.Interface(
    fn=get_weather,
    inputs=gr.Textbox(label="Enter City Name", placeholder="e.g., Dubai, London, Tokyo"),
    outputs=gr.Textbox(label="Weather Update"),
    title="🌤️ Karthick's Weather Bot",
    description="Live weather details",
    theme="gradio/soft",
    css=custom_css
)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b0b6fa08f9bf958d8f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b0b6fa08f9bf958d8f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        return f"The current temperature in {city} is {temp}°C with {description}."
    else:
        return "Sorry, I couldn't find weather information for that city."

custom_css = """
body {
    background: linear-gradient(120deg, #FFCF71, #FDB36B, #FF8C6A, #FF6F91);
    background-size: 400% 400%;
    animation: sunriseBG 15s ease infinite;
}

/* Sunrise gradient motion */
@keyframes sunriseBG {
    0% { background-position: 0% 50%; }
    50% { background-position: 100% 50%; }
    100% { background-position: 0% 50%; }
}

/* Soft golden sparkles */
body::before {
    content: "";
    position: fixed;
    top: 0; left: 0;
    width: 100%; height: 100%;
    pointer-events: none;
    background-image: radial-gradient(rgba(255,255,255,0.8) 1px, transparent 1px);
    background-size: 5px 5px;
    opacity: 0.15;
    animation: sparkle 5s linear infinite;
}

@keyframes sparkle {
    0% { opacity: 0.1; }
    50% { opacity: 0.25; }
    100% { opacity: 0.1; }
}

/* Frosted glass card */
.gradio-container {
    border-radius: 20px;
    padding: 25px !important;
    background: rgba(255, 255, 255, 0.4) !important;
    box-shadow: 0 0 25px rgba(255, 150, 80, 0.3);
    backdrop-filter: blur(10px);
}

input, textarea {
    border-radius: 12px !important;
}
"""

iface = gr.Interface(
    fn=get_weather,
    inputs=gr.Textbox(label="Enter City Name", placeholder="e.g., Dubai, London, Tokyo"),
    outputs=gr.Textbox(label="Weather Update"),
    title="🌅 Karthick's First App",
    description="Get live weather updates with a warm sunrise background.",
    theme="gradio/soft",
    css=custom_css
)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f5805a21db3fb35bab.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f5805a21db3fb35bab.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        return f"The current temperature in {city} is {temp}°C with {description}."
    else:
        return "Sorry, I couldn't find weather information for that city."

iface = gr.Interface(fn=get_weather, inputs="text", outputs="text")
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ab934b93440e2cbfe8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ab934b93440e2cbfe8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
